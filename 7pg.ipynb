# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen

url="https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data"

np.set_printoptions(threshold=np.inf)
names=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','heartdisease']
hd=pd.read_csv(urlopen(url),names=names)
hd.head() 
del hd['ca'] 
del hd['slope'] 
del hd['thal'] 
del hd['oldpeak'] 
hd = hd.replace('?', np.nan) 
hd.dtypes 
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator

model=BayesianModel([('age','trestbps'),('age','fbs'),('sex','trestbps'),('exang', 'trestbps'),
                       ('trestbps','heartdisease'),( 'fbs','heartdisease'),
                       ('heartdisease','restecg'),('heartdisease','thalach' ),('heartdisease','chol')])  
model.fit(hd, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age'))
print(model.get_cpds('sex'))
print(model.get_cpds('chol'))
print(model.get_independencies())
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ chol, thalach, restecg | heartdisease)
# (age _|_ exang, sex | fbs)
# (age _|_ restecg, thalach | chol, heartdisease)
# (age _|_ chol, restecg, thalach | trestbps, heartdisease)
# (age _|_ chol, restecg, heartdisease, thalach | trestbps, fbs)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ chol, restecg | heartdisease, thalach)
# (age _|_ chol, restecg, thalach | exang, heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ chol, restecg, thalach | sex, heartdisease)
# (age _|_ exang | sex, fbs)
# (age _|_ chol, restecg, thalach | heartdisease, fbs)
# (age _|_ restecg, thalach | chol, trestbps, heartdisease)
# (age _|_ restecg, heartdisease, thalach | chol, trestbps, fbs)
# (age _|_ thalach | chol, heartdisease, restecg)
# (age _|_ restecg | chol, heartdisease, thalach)
# (age _|_ restecg, thalach | chol, heartdisease, exang)
# (age _|_ restecg, thalach | chol, sex, heartdisease)
# (age _|_ restecg, thalach | chol, heartdisease, fbs)
# (age _|_ chol, thalach | trestbps, heartdisease, restecg)
# (age _|_ chol, heartdisease, thalach | fbs, trestbps, restecg)
# (age _|_ chol, restecg | trestbps, heartdisease, thalach)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, thalach)
# (age _|_ chol, restecg, thalach | exang, trestbps, heartdisease)
# (age _|_ chol, restecg, heartdisease, thalach | exang, trestbps, fbs)
# (age _|_ chol, restecg, thalach | trestbps, sex, heartdisease)
# (age _|_ chol, restecg, heartdisease, thalach | trestbps, sex, fbs)
# (age _|_ chol, restecg, thalach | trestbps, heartdisease, fbs)
# (age _|_ chol | thalach, heartdisease, restecg)
# (age _|_ chol, thalach | exang, heartdisease, restecg)
# (age _|_ chol, thalach | sex, heartdisease, restecg)
# (age _|_ chol, thalach | fbs, heartdisease, restecg)
# (age _|_ chol, restecg | exang, heartdisease, thalach)
# (age _|_ chol, restecg | sex, heartdisease, thalach)
# (age _|_ chol, restecg | fbs, heartdisease, thalach)
# (age _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (age _|_ chol, restecg, thalach | exang, heartdisease, fbs)
# (age _|_ chol, restecg, thalach | sex, heartdisease, fbs)
# (age _|_ thalach | chol, trestbps, heartdisease, restecg)
# (age _|_ heartdisease, thalach | chol, trestbps, fbs, restecg)
# (age _|_ restecg | chol, trestbps, heartdisease, thalach)
# (age _|_ heartdisease, restecg | chol, trestbps, fbs, thalach)
# (age _|_ restecg, thalach | chol, trestbps, heartdisease, exang)
# (age _|_ restecg, heartdisease, thalach | chol, trestbps, exang, fbs)
# (age _|_ restecg, thalach | chol, trestbps, sex, heartdisease)
# (age _|_ restecg, heartdisease, thalach | chol, trestbps, sex, fbs)
# (age _|_ restecg, thalach | chol, trestbps, heartdisease, fbs)
# (age _|_ thalach | chol, heartdisease, exang, restecg)
# (age _|_ thalach | chol, sex, heartdisease, restecg)
# (age _|_ thalach | chol, fbs, heartdisease, restecg)
# (age _|_ restecg | chol, heartdisease, exang, thalach)
# (age _|_ restecg | chol, sex, heartdisease, thalach)
# (age _|_ restecg | chol, fbs, heartdisease, thalach)
# (age _|_ restecg, thalach | chol, heartdisease, sex, exang)
# (age _|_ restecg, thalach | chol, heartdisease, exang, fbs)
# (age _|_ restecg, thalach | chol, sex, heartdisease, fbs)
# (age _|_ chol | thalach, trestbps, heartdisease, restecg)
# (age _|_ chol, heartdisease | fbs, thalach, trestbps, restecg)
# (age _|_ chol, thalach | exang, trestbps, heartdisease, restecg)
# (age _|_ chol, heartdisease, thalach | exang, trestbps, fbs, restecg)
# (age _|_ chol, thalach | trestbps, sex, heartdisease, restecg)
# (age _|_ chol, heartdisease, thalach | fbs, trestbps, sex, restecg)
# (age _|_ chol, thalach | fbs, trestbps, heartdisease, restecg)
# (age _|_ chol, restecg | exang, trestbps, heartdisease, thalach)
# (age _|_ chol, heartdisease, restecg | exang, trestbps, fbs, thalach)
# (age _|_ chol, restecg | trestbps, sex, heartdisease, thalach)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, sex, thalach)
# (age _|_ chol, restecg | fbs, trestbps, heartdisease, thalach)
# (age _|_ chol, restecg, thalach | exang, trestbps, sex, heartdisease)
# (age _|_ chol, restecg, heartdisease, thalach | exang, trestbps, sex, fbs)
# (age _|_ chol, restecg, thalach | exang, trestbps, heartdisease, fbs)
# (age _|_ chol, restecg, thalach | trestbps, sex, heartdisease, fbs)
# (age _|_ chol | exang, thalach, heartdisease, restecg)
# (age _|_ chol | thalach, sex, heartdisease, restecg)
# (age _|_ chol | fbs, thalach, heartdisease, restecg)
# (age _|_ chol, thalach | exang, sex, heartdisease, restecg)
# (age _|_ chol, thalach | exang, fbs, heartdisease, restecg)
# (age _|_ chol, thalach | fbs, sex, heartdisease, restecg)
# (age _|_ chol, restecg | exang, sex, heartdisease, thalach)
# (age _|_ chol, restecg | exang, fbs, heartdisease, thalach)
# (age _|_ chol, restecg | fbs, sex, heartdisease, thalach)
# (age _|_ chol, restecg, thalach | exang, sex, heartdisease, fbs)
# (age _|_ heartdisease | chol, trestbps, thalach, restecg, fbs)
# (age _|_ thalach | chol, trestbps, restecg, exang, heartdisease)
# (age _|_ heartdisease, thalach | chol, trestbps, restecg, exang, fbs)
# (age _|_ thalach | chol, trestbps, restecg, sex, heartdisease)
# (age _|_ heartdisease, thalach | chol, trestbps, restecg, sex, fbs)
# (age _|_ thalach | chol, trestbps, restecg, heartdisease, fbs)
# (age _|_ restecg | chol, trestbps, thalach, exang, heartdisease)
# (age _|_ heartdisease, restecg | chol, trestbps, thalach, exang, fbs)
# (age _|_ restecg | chol, trestbps, thalach, sex, heartdisease)
# (age _|_ heartdisease, restecg | chol, trestbps, thalach, sex, fbs)
# (age _|_ restecg | chol, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg, thalach | chol, trestbps, exang, sex, heartdisease)
# (age _|_ restecg, heartdisease, thalach | chol, trestbps, exang, sex, fbs)
# (age _|_ restecg, thalach | chol, trestbps, exang, heartdisease, fbs)
# (age _|_ restecg, thalach | chol, trestbps, sex, heartdisease, fbs)
# (age _|_ thalach | chol, restecg, exang, sex, heartdisease)
# (age _|_ thalach | chol, restecg, exang, heartdisease, fbs)
# (age _|_ thalach | chol, restecg, sex, heartdisease, fbs)
# (age _|_ restecg | chol, thalach, exang, sex, heartdisease)
# (age _|_ restecg | chol, thalach, exang, heartdisease, fbs)
# (age _|_ restecg | chol, thalach, sex, heartdisease, fbs)
# (age _|_ restecg, thalach | chol, exang, sex, heartdisease, fbs)
# (age _|_ chol | trestbps, thalach, restecg, exang, heartdisease)
# (age _|_ chol, heartdisease | trestbps, thalach, restecg, exang, fbs)
# (age _|_ chol | trestbps, thalach, restecg, sex, heartdisease)
# (age _|_ chol, heartdisease | trestbps, thalach, restecg, sex, fbs)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, fbs)
# (age _|_ chol, thalach | trestbps, restecg, exang, sex, heartdisease)
# (age _|_ chol, heartdisease, thalach | trestbps, restecg, exang, sex, fbs)
# (age _|_ chol, thalach | trestbps, restecg, exang, heartdisease, fbs)
# (age _|_ chol, thalach | trestbps, restecg, sex, heartdisease, fbs)
# (age _|_ chol, restecg | trestbps, thalach, exang, sex, heartdisease)
# (age _|_ chol, heartdisease, restecg | trestbps, thalach, exang, sex, fbs)
# (age _|_ chol, restecg | trestbps, thalach, exang, heartdisease, fbs)
# (age _|_ chol, restecg | trestbps, thalach, sex, heartdisease, fbs)
# (age _|_ chol, restecg, thalach | trestbps, exang, sex, heartdisease, fbs)
# (age _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (age _|_ chol | thalach, restecg, exang, heartdisease, fbs)
# (age _|_ chol | thalach, restecg, sex, heartdisease, fbs)
# (age _|_ chol, thalach | restecg, exang, sex, heartdisease, fbs)
# (age _|_ chol, restecg | thalach, exang, sex, heartdisease, fbs)
# (age _|_ heartdisease | chol, trestbps, thalach, restecg, exang, fbs)
# (age _|_ heartdisease | chol, trestbps, thalach, restecg, sex, fbs)
# (age _|_ thalach | chol, trestbps, restecg, exang, sex, heartdisease)
# (age _|_ heartdisease, thalach | chol, trestbps, restecg, exang, sex, fbs)
# (age _|_ thalach | chol, trestbps, restecg, exang, heartdisease, fbs)
# (age _|_ thalach | chol, trestbps, restecg, sex, heartdisease, fbs)
# (age _|_ restecg | chol, trestbps, thalach, exang, sex, heartdisease)
# (age _|_ heartdisease, restecg | chol, trestbps, thalach, exang, sex, fbs)
# (age _|_ restecg | chol, trestbps, thalach, exang, heartdisease, fbs)
# (age _|_ restecg | chol, trestbps, thalach, sex, heartdisease, fbs)
# (age _|_ restecg, thalach | chol, trestbps, exang, sex, heartdisease, fbs)
# (age _|_ thalach | chol, restecg, exang, sex, heartdisease, fbs)
# (age _|_ restecg | chol, thalach, exang, sex, heartdisease, fbs)
# (age _|_ chol | trestbps, thalach, restecg, exang, sex, heartdisease)
# (age _|_ chol, heartdisease | trestbps, thalach, restecg, exang, sex, fbs)
# (age _|_ chol | trestbps, thalach, restecg, exang, heartdisease, fbs)
# (age _|_ chol | trestbps, thalach, restecg, sex, heartdisease, fbs)
# (age _|_ chol, thalach | trestbps, restecg, exang, sex, heartdisease, fbs)
# (age _|_ chol, restecg | trestbps, thalach, exang, sex, heartdisease, fbs)
# (age _|_ chol | thalach, restecg, exang, sex, heartdisease, fbs)
# (age _|_ heartdisease | chol, trestbps, thalach, restecg, exang, sex, fbs)
# (age _|_ thalach | chol, trestbps, restecg, exang, sex, heartdisease, fbs)
# (age _|_ restecg | chol, trestbps, thalach, exang, sex, heartdisease, fbs)
# (age _|_ chol | trestbps, thalach, restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, thalach, restecg | heartdisease)
# (trestbps _|_ restecg, thalach | chol, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ chol, restecg, thalach | age, heartdisease)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ chol, restecg | heartdisease, thalach)
# (trestbps _|_ chol, restecg, thalach | exang, heartdisease)
# (trestbps _|_ chol, restecg, thalach | sex, heartdisease)
# (trestbps _|_ chol, restecg, thalach | heartdisease, fbs)
# (trestbps _|_ restecg, thalach | chol, age, heartdisease)
# (trestbps _|_ thalach | chol, heartdisease, restecg)
# (trestbps _|_ restecg | chol, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | chol, heartdisease, exang)
# (trestbps _|_ restecg, thalach | chol, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, heartdisease, fbs)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg)
# (trestbps _|_ chol, restecg | age, heartdisease, thalach)
# (trestbps _|_ fbs | exang, age, sex)
# (trestbps _|_ chol, restecg, thalach | exang, age, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, sex, heartdisease)
# (trestbps _|_ chol, restecg, thalach | age, heartdisease, fbs)
# (trestbps _|_ chol | thalach, heartdisease, restecg)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg)
# (trestbps _|_ chol, thalach | fbs, heartdisease, restecg)
# (trestbps _|_ chol, restecg | exang, heartdisease, thalach)
# (trestbps _|_ chol, restecg | sex, heartdisease, thalach)
# (trestbps _|_ chol, restecg | fbs, heartdisease, thalach)
# (trestbps _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (trestbps _|_ chol, restecg, thalach | exang, heartdisease, fbs)
# (trestbps _|_ chol, restecg, thalach | sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, heartdisease, restecg)
# (trestbps _|_ restecg | chol, age, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | chol, age, heartdisease, exang)
# (trestbps _|_ restecg, thalach | chol, age, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, heartdisease, fbs)
# (trestbps _|_ thalach | chol, heartdisease, exang, restecg)
# (trestbps _|_ thalach | chol, sex, heartdisease, restecg)
# (trestbps _|_ thalach | chol, fbs, heartdisease, restecg)
# (trestbps _|_ restecg | chol, heartdisease, exang, thalach)
# (trestbps _|_ restecg | chol, sex, heartdisease, thalach)
# (trestbps _|_ restecg | chol, fbs, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | chol, heartdisease, sex, exang)
# (trestbps _|_ restecg, thalach | chol, heartdisease, exang, fbs)
# (trestbps _|_ restecg, thalach | chol, sex, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, heartdisease, restecg)
# (trestbps _|_ chol, thalach | exang, age, heartdisease, restecg)
# (trestbps _|_ chol, thalach | age, sex, heartdisease, restecg)
# (trestbps _|_ chol, thalach | fbs, age, heartdisease, restecg)
# (trestbps _|_ chol, restecg | exang, age, heartdisease, thalach)
# (trestbps _|_ chol, restecg | age, sex, heartdisease, thalach)
# (trestbps _|_ chol, restecg | fbs, age, heartdisease, thalach)
# (trestbps _|_ chol, restecg, thalach | exang, age, sex, heartdisease)
# (trestbps _|_ chol, restecg, thalach | exang, age, heartdisease, fbs)
# (trestbps _|_ chol, restecg, thalach | age, sex, heartdisease, fbs)
# (trestbps _|_ chol | exang, thalach, heartdisease, restecg)
# (trestbps _|_ chol | thalach, sex, heartdisease, restecg)
# (trestbps _|_ chol | fbs, thalach, heartdisease, restecg)
# (trestbps _|_ chol, thalach | exang, sex, heartdisease, restecg)
# (trestbps _|_ chol, thalach | exang, fbs, heartdisease, restecg)
# (trestbps _|_ chol, thalach | fbs, sex, heartdisease, restecg)
# (trestbps _|_ chol, restecg | exang, sex, heartdisease, thalach)
# (trestbps _|_ chol, restecg | exang, fbs, heartdisease, thalach)
# (trestbps _|_ chol, restecg | fbs, sex, heartdisease, thalach)
# (trestbps _|_ chol, restecg, thalach | exang, sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, restecg, exang, heartdisease)
# (trestbps _|_ thalach | chol, age, restecg, sex, heartdisease)
# (trestbps _|_ thalach | chol, age, restecg, heartdisease, fbs)
# (trestbps _|_ restecg | chol, age, thalach, exang, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, sex, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | chol, age, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, age, exang, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | chol, age, sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach | chol, restecg, exang, heartdisease, fbs)
# (trestbps _|_ thalach | chol, restecg, sex, heartdisease, fbs)
# (trestbps _|_ restecg | chol, thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg | chol, thalach, exang, heartdisease, fbs)
# (trestbps _|_ restecg | chol, thalach, sex, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | chol, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, sex, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, heartdisease, fbs)
# (trestbps _|_ chol, thalach | age, restecg, exang, sex, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, exang, heartdisease, fbs)
# (trestbps _|_ chol, thalach | age, restecg, sex, heartdisease, fbs)
# (trestbps _|_ chol, restecg | age, thalach, exang, sex, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, exang, heartdisease, fbs)
# (trestbps _|_ chol, restecg | age, thalach, sex, heartdisease, fbs)
# (trestbps _|_ chol, restecg, thalach | age, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ chol | thalach, restecg, exang, heartdisease, fbs)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, fbs)
# (trestbps _|_ chol, thalach | restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol, restecg | thalach, exang, sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach | chol, age, restecg, exang, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, restecg, sex, heartdisease, fbs)
# (trestbps _|_ restecg | chol, age, thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, exang, heartdisease, fbs)
# (trestbps _|_ restecg | chol, age, thalach, sex, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | chol, age, exang, sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ restecg | chol, thalach, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, exang, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, restecg, sex, heartdisease, fbs)
# (trestbps _|_ chol, thalach | age, restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol, restecg | age, thalach, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol | thalach, restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ thalach | chol, age, restecg, exang, sex, heartdisease, fbs)
# (trestbps _|_ restecg | chol, age, thalach, exang, sex, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, restecg, exang, sex, heartdisease, fbs)
# (fbs _|_ exang, sex)
# (fbs _|_ exang, trestbps, sex | age)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ chol, thalach, restecg | heartdisease)
# (fbs _|_ restecg, thalach | chol, heartdisease)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ trestbps, sex | exang, age)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ chol, restecg, thalach | age, heartdisease)
# (fbs _|_ chol, restecg, thalach | trestbps, heartdisease)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ chol, restecg | heartdisease, thalach)
# (fbs _|_ chol, restecg, thalach | exang, heartdisease)
# (fbs _|_ chol, restecg, thalach | sex, heartdisease)
# (fbs _|_ exang, sex | chol, age, trestbps)
# (fbs _|_ restecg, thalach | chol, age, heartdisease)
# (fbs _|_ restecg, thalach | chol, trestbps, heartdisease)
# (fbs _|_ thalach | chol, heartdisease, restecg)
# (fbs _|_ restecg | chol, heartdisease, thalach)
# (fbs _|_ restecg, thalach | chol, heartdisease, exang)
# (fbs _|_ restecg, thalach | chol, sex, heartdisease)
# (fbs _|_ exang, sex | age, trestbps, restecg)
# (fbs _|_ exang, sex | age, trestbps, thalach)
# (fbs _|_ sex | exang, age, trestbps)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ chol, thalach, exang, sex, restecg | age, trestbps, heartdisease)
# (fbs _|_ chol, thalach | age, heartdisease, restecg)
# (fbs _|_ chol, restecg | age, heartdisease, thalach)
# (fbs _|_ trestbps | exang, age, sex)
# (fbs _|_ chol, restecg, thalach | exang, age, heartdisease)
# (fbs _|_ chol, restecg, thalach | age, sex, heartdisease)
# (fbs _|_ chol, thalach | trestbps, heartdisease, restecg)
# (fbs _|_ chol, restecg | trestbps, heartdisease, thalach)
# (fbs _|_ chol, restecg, thalach | exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg, thalach | trestbps, sex, heartdisease)
# (fbs _|_ chol | thalach, heartdisease, restecg)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, heartdisease, thalach)
# (fbs _|_ chol, restecg | sex, heartdisease, thalach)
# (fbs _|_ chol, restecg, thalach | exang, sex, heartdisease)
# (fbs _|_ exang, sex | chol, age, trestbps, restecg)
# (fbs _|_ exang, sex | chol, age, trestbps, thalach)
# (fbs _|_ sex | chol, age, trestbps, exang)
# (fbs _|_ exang | chol, age, trestbps, sex)
# (fbs _|_ exang, sex, restecg, thalach | chol, age, trestbps, heartdisease)
# (fbs _|_ thalach | chol, age, heartdisease, restecg)
# (fbs _|_ restecg | chol, age, heartdisease, thalach)
# (fbs _|_ restecg, thalach | chol, age, heartdisease, exang)
# (fbs _|_ restecg, thalach | chol, age, sex, heartdisease)
# (fbs _|_ thalach | chol, trestbps, heartdisease, restecg)
# (fbs _|_ restecg | chol, trestbps, heartdisease, thalach)
# (fbs _|_ restecg, thalach | chol, trestbps, heartdisease, exang)
# (fbs _|_ restecg, thalach | chol, trestbps, sex, heartdisease)
# (fbs _|_ thalach | chol, heartdisease, exang, restecg)
# (fbs _|_ thalach | chol, sex, heartdisease, restecg)
# (fbs _|_ restecg | chol, heartdisease, exang, thalach)
# (fbs _|_ restecg | chol, sex, heartdisease, thalach)
# (fbs _|_ restecg, thalach | chol, heartdisease, sex, exang)
# (fbs _|_ exang, sex | age, trestbps, thalach, restecg)
# (fbs _|_ sex | exang, age, trestbps, restecg)
# (fbs _|_ exang | age, trestbps, sex, restecg)
# (fbs _|_ chol, sex, exang, thalach | age, trestbps, heartdisease, restecg)
# (fbs _|_ sex | exang, age, trestbps, thalach)
# (fbs _|_ exang | age, trestbps, sex, thalach)
# (fbs _|_ chol, sex, exang, restecg | age, trestbps, heartdisease, thalach)
# (fbs _|_ chol, sex, restecg, thalach | exang, age, trestbps, heartdisease)
# (fbs _|_ chol, restecg, exang, thalach | age, trestbps, sex, heartdisease)
# (fbs _|_ chol | age, thalach, heartdisease, restecg)
# (fbs _|_ chol, thalach | exang, age, heartdisease, restecg)
# (fbs _|_ chol, thalach | age, sex, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, age, heartdisease, thalach)
# (fbs _|_ chol, restecg | age, sex, heartdisease, thalach)
# (fbs _|_ chol, restecg, thalach | exang, age, sex, heartdisease)
# (fbs _|_ chol | thalach, trestbps, heartdisease, restecg)
# (fbs _|_ chol, thalach | exang, trestbps, heartdisease, restecg)
# (fbs _|_ chol, thalach | trestbps, sex, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, trestbps, heartdisease, thalach)
# (fbs _|_ chol, restecg | trestbps, sex, heartdisease, thalach)
# (fbs _|_ chol, restecg, thalach | exang, trestbps, sex, heartdisease)
# (fbs _|_ chol | exang, thalach, heartdisease, restecg)
# (fbs _|_ chol | thalach, sex, heartdisease, restecg)
# (fbs _|_ chol, thalach | exang, sex, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, sex, heartdisease, thalach)
# (fbs _|_ exang, sex | chol, age, trestbps, thalach, restecg)
# (fbs _|_ sex | chol, age, trestbps, restecg, exang)
# (fbs _|_ exang | chol, age, trestbps, restecg, sex)
# (fbs _|_ exang, sex, thalach | chol, age, trestbps, restecg, heartdisease)
# (fbs _|_ sex | chol, age, trestbps, thalach, exang)
# (fbs _|_ exang | chol, age, trestbps, thalach, sex)
# (fbs _|_ exang, sex, restecg | chol, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, sex, thalach | chol, age, trestbps, exang, heartdisease)
# (fbs _|_ exang, restecg, thalach | chol, age, trestbps, sex, heartdisease)
# (fbs _|_ thalach | chol, age, restecg, exang, heartdisease)
# (fbs _|_ thalach | chol, age, restecg, sex, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, exang, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, sex, heartdisease)
# (fbs _|_ restecg, thalach | chol, age, exang, sex, heartdisease)
# (fbs _|_ thalach | chol, trestbps, restecg, exang, heartdisease)
# (fbs _|_ thalach | chol, trestbps, restecg, sex, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, exang, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg, thalach | chol, trestbps, exang, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, exang, sex, heartdisease)
# (fbs _|_ restecg | chol, thalach, exang, sex, heartdisease)
# (fbs _|_ sex | age, trestbps, thalach, restecg, exang)
# (fbs _|_ exang | age, trestbps, thalach, restecg, sex)
# (fbs _|_ chol, sex, exang | age, trestbps, thalach, restecg, heartdisease)
# (fbs _|_ chol, sex, thalach | age, trestbps, restecg, exang, heartdisease)
# (fbs _|_ chol, exang, thalach | age, trestbps, restecg, sex, heartdisease)
# (fbs _|_ chol, sex, restecg | age, trestbps, thalach, exang, heartdisease)
# (fbs _|_ chol, exang, restecg | age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol, restecg, thalach | age, trestbps, exang, sex, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, exang, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | age, restecg, exang, sex, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, exang, sex, heartdisease)
# (fbs _|_ chol | trestbps, thalach, restecg, exang, heartdisease)
# (fbs _|_ chol | trestbps, thalach, restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, exang, sex, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, exang, sex, heartdisease)
# (fbs _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (fbs _|_ sex | chol, age, trestbps, thalach, restecg, exang)
# (fbs _|_ exang | chol, age, trestbps, thalach, restecg, sex)
# (fbs _|_ exang, sex | chol, age, trestbps, thalach, restecg, heartdisease)
# (fbs _|_ sex, thalach | chol, age, trestbps, restecg, exang, heartdisease)
# (fbs _|_ exang, thalach | chol, age, trestbps, restecg, sex, heartdisease)
# (fbs _|_ sex, restecg | chol, age, trestbps, thalach, exang, heartdisease)
# (fbs _|_ exang, restecg | chol, age, trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg, thalach | chol, age, trestbps, exang, sex, heartdisease)
# (fbs _|_ thalach | chol, age, restecg, exang, sex, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, exang, sex, heartdisease)
# (fbs _|_ thalach | chol, trestbps, restecg, exang, sex, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, exang, sex, heartdisease)
# (fbs _|_ chol, sex | age, trestbps, thalach, restecg, exang, heartdisease)
# (fbs _|_ chol, exang | age, trestbps, thalach, restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | age, trestbps, restecg, exang, sex, heartdisease)
# (fbs _|_ chol, restecg | age, trestbps, thalach, exang, sex, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, exang, sex, heartdisease)
# (fbs _|_ chol | trestbps, thalach, restecg, exang, sex, heartdisease)
# (fbs _|_ sex | chol, age, trestbps, thalach, restecg, exang, heartdisease)
# (fbs _|_ exang | chol, age, trestbps, thalach, restecg, sex, heartdisease)
# (fbs _|_ thalach | chol, age, trestbps, restecg, exang, sex, heartdisease)
# (fbs _|_ restecg | chol, age, trestbps, thalach, exang, sex, heartdisease)
# (fbs _|_ chol | age, trestbps, thalach, restecg, exang, sex, heartdisease)
# (sex _|_ exang, age, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, fbs | exang)
# (sex _|_ chol, thalach, restecg | heartdisease)
# (sex _|_ exang, age | fbs)
# (sex _|_ restecg, thalach | chol, heartdisease)
# (sex _|_ chol, thalach, heartdisease, restecg, fbs | age, trestbps)
# (sex _|_ fbs | exang, age)
# (sex _|_ chol, restecg, thalach | age, heartdisease)
# (sex _|_ exang | age, fbs)
# (sex _|_ chol, restecg, thalach | trestbps, heartdisease)
# (sex _|_ chol, restecg, heartdisease, thalach | trestbps, fbs)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ chol, restecg | heartdisease, thalach)
# (sex _|_ chol, restecg, thalach | exang, heartdisease)
# (sex _|_ age | exang, fbs)
# (sex _|_ chol, restecg, thalach | heartdisease, fbs)
# (sex _|_ restecg, fbs, heartdisease, thalach | chol, age, trestbps)
# (sex _|_ restecg, thalach | chol, age, heartdisease)
# (sex _|_ restecg, thalach | chol, trestbps, heartdisease)
# (sex _|_ restecg, heartdisease, thalach | chol, trestbps, fbs)
# (sex _|_ thalach | chol, heartdisease, restecg)
# (sex _|_ restecg | chol, heartdisease, thalach)
# (sex _|_ restecg, thalach | chol, heartdisease, exang)
# (sex _|_ restecg, thalach | chol, heartdisease, fbs)
# (sex _|_ chol, fbs, heartdisease, thalach | age, trestbps, restecg)
# ...
# (thalach _|_ age, sex | chol, trestbps, restecg, exang, fbs)
# (thalach _|_ exang, age, fbs | chol, trestbps, restecg, sex, heartdisease)
# (thalach _|_ exang, age | chol, trestbps, restecg, sex, fbs)
# (thalach _|_ exang, age, sex | chol, trestbps, restecg, heartdisease, fbs)
# (thalach _|_ restecg, age, fbs | chol, trestbps, exang, sex, heartdisease)
# (thalach _|_ age | chol, trestbps, exang, sex, fbs)
# (thalach _|_ age, sex, restecg | chol, trestbps, exang, heartdisease, fbs)
# (thalach _|_ exang, age, restecg | chol, trestbps, sex, heartdisease, fbs)
# (thalach _|_ age, trestbps, fbs | chol, restecg, exang, sex, heartdisease)
# (thalach _|_ age, trestbps, sex | chol, restecg, exang, heartdisease, fbs)
# (thalach _|_ exang, age, trestbps | chol, restecg, sex, heartdisease, fbs)
# (thalach _|_ age, trestbps, restecg | chol, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, sex, fbs | age, trestbps, restecg, exang, heartdisease)
# (thalach _|_ sex | age, trestbps, restecg, exang, fbs)
# (thalach _|_ chol, exang, fbs | age, trestbps, restecg, sex, heartdisease)
# (thalach _|_ exang | age, trestbps, restecg, sex, fbs)
# (thalach _|_ chol, sex, exang | age, trestbps, restecg, heartdisease, fbs)
# (thalach _|_ chol, restecg, fbs | age, trestbps, exang, sex, heartdisease)
# (thalach _|_ chol, sex, restecg | age, trestbps, exang, heartdisease, fbs)
# (thalach _|_ chol, exang, restecg | age, trestbps, sex, heartdisease, fbs)
# (thalach _|_ chol, trestbps, fbs | age, restecg, exang, sex, heartdisease)
# (thalach _|_ chol, trestbps, sex | age, restecg, exang, heartdisease, fbs)
# (thalach _|_ chol, trestbps, exang | age, restecg, sex, heartdisease, fbs)
# (thalach _|_ chol, trestbps, restecg | age, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, age, fbs | trestbps, restecg, exang, sex, heartdisease)
# (thalach _|_ age | trestbps, restecg, exang, sex, fbs)
# (thalach _|_ chol, age, sex | trestbps, restecg, exang, heartdisease, fbs)
# (thalach _|_ chol, age, exang | trestbps, restecg, sex, heartdisease, fbs)
# (thalach _|_ chol, age, restecg | trestbps, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, age, trestbps | restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ sex, fbs | chol, age, trestbps, restecg, exang, heartdisease)
# (thalach _|_ sex | chol, age, trestbps, restecg, exang, fbs)
# (thalach _|_ exang, fbs | chol, age, trestbps, restecg, sex, heartdisease)
# (thalach _|_ exang | chol, age, trestbps, restecg, sex, fbs)
# (thalach _|_ exang, sex | chol, age, trestbps, restecg, heartdisease, fbs)
# (thalach _|_ restecg, fbs | chol, age, trestbps, exang, sex, heartdisease)
# (thalach _|_ sex, restecg | chol, age, trestbps, exang, heartdisease, fbs)
# (thalach _|_ exang, restecg | chol, age, trestbps, sex, heartdisease, fbs)
# (thalach _|_ trestbps, fbs | chol, age, restecg, exang, sex, heartdisease)
# (thalach _|_ trestbps, sex | chol, age, restecg, exang, heartdisease, fbs)
# (thalach _|_ exang, trestbps | chol, age, restecg, sex, heartdisease, fbs)
# (thalach _|_ trestbps, restecg | chol, age, exang, sex, heartdisease, fbs)
# (thalach _|_ age, fbs | chol, trestbps, restecg, exang, sex, heartdisease)
# (thalach _|_ age | chol, trestbps, restecg, exang, sex, fbs)
# (thalach _|_ age, sex | chol, trestbps, restecg, exang, heartdisease, fbs)
# (thalach _|_ exang, age | chol, trestbps, restecg, sex, heartdisease, fbs)
# (thalach _|_ age, restecg | chol, trestbps, exang, sex, heartdisease, fbs)
# (thalach _|_ age, trestbps | chol, restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, fbs | age, trestbps, restecg, exang, sex, heartdisease)
# (thalach _|_ chol, sex | age, trestbps, restecg, exang, heartdisease, fbs)
# (thalach _|_ chol, exang | age, trestbps, restecg, sex, heartdisease, fbs)
# (thalach _|_ chol, restecg | age, trestbps, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, trestbps | age, restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ chol, age | trestbps, restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ fbs | chol, age, trestbps, restecg, exang, sex, heartdisease)
# (thalach _|_ sex | chol, age, trestbps, restecg, exang, heartdisease, fbs)
# (thalach _|_ exang | chol, age, trestbps, restecg, sex, heartdisease, fbs)
# (thalach _|_ restecg | chol, age, trestbps, exang, sex, heartdisease, fbs)
# (thalach _|_ trestbps | chol, age, restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ age | chol, trestbps, restecg, exang, sex, heartdisease, fbs)
# (thalach _|_ chol | age, trestbps, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ restecg, age, trestbps, exang, sex, thalach, fbs | heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ exang, thalach, trestbps, sex, restecg, fbs | age, heartdisease)
# (chol _|_ exang, age, thalach, sex, restecg, fbs | trestbps, heartdisease)
# (chol _|_ exang, age, sex | trestbps, fbs)
# (chol _|_ exang, age, trestbps, sex, thalach, fbs | heartdisease, restecg)
# (chol _|_ exang, age, trestbps, sex, restecg, fbs | heartdisease, thalach)
# (chol _|_ age, trestbps, thalach, sex, restecg, fbs | exang, heartdisease)
# (chol _|_ exang, age, trestbps, thalach, restecg, fbs | sex, heartdisease)
# (chol _|_ exang, age, trestbps, thalach, sex, restecg | heartdisease, fbs)
# (chol _|_ exang, sex | age, trestbps, restecg)
# (chol _|_ exang, sex | age, trestbps, thalach)
# (chol _|_ sex | exang, age, trestbps)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ exang, thalach, sex, restecg, fbs | age, trestbps, heartdisease)
# (chol _|_ exang, sex | age, trestbps, fbs)
# (chol _|_ exang, trestbps, sex, thalach, fbs | age, heartdisease, restecg)
# (chol _|_ exang, trestbps, sex, restecg, fbs | age, heartdisease, thalach)
# (chol _|_ thalach, trestbps, sex, restecg, fbs | exang, age, heartdisease)
# (chol _|_ exang, thalach, trestbps, restecg, fbs | age, sex, heartdisease)
# (chol _|_ exang, thalach, trestbps, sex, restecg | age, heartdisease, fbs)
# (chol _|_ exang, age, sex, thalach, fbs | trestbps, heartdisease, restecg)
# (chol _|_ exang, age, sex | fbs, trestbps, restecg)
# (chol _|_ exang, age, sex, restecg, fbs | trestbps, heartdisease, thalach)
# (chol _|_ exang, age, sex | fbs, trestbps, thalach)
# (chol _|_ age, thalach, sex, restecg, fbs | exang, trestbps, heartdisease)
# (chol _|_ age, sex | exang, trestbps, fbs)
# (chol _|_ exang, age, thalach, restecg, fbs | trestbps, sex, heartdisease)
# (chol _|_ exang, age | trestbps, sex, fbs)
# (chol _|_ exang, age, thalach, sex, restecg | trestbps, heartdisease, fbs)
# (chol _|_ exang, age, trestbps, sex, fbs | thalach, heartdisease, restecg)
# (chol _|_ age, trestbps, sex, thalach, fbs | exang, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, thalach, fbs | sex, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, sex, thalach | fbs, heartdisease, restecg)
# (chol _|_ age, trestbps, sex, restecg, fbs | exang, heartdisease, thalach)
# (chol _|_ exang, age, trestbps, restecg, fbs | sex, heartdisease, thalach)
# (chol _|_ exang, age, trestbps, sex, restecg | fbs, heartdisease, thalach)
# (chol _|_ age, trestbps, thalach, restecg, fbs | exang, sex, heartdisease)
# (chol _|_ age, trestbps, thalach, sex, restecg | exang, heartdisease, fbs)
# (chol _|_ exang, age, trestbps, thalach, restecg | sex, heartdisease, fbs)
# (chol _|_ exang, sex | age, trestbps, thalach, restecg)
# (chol _|_ sex | exang, age, trestbps, restecg)
# (chol _|_ exang | age, trestbps, sex, restecg)
# (chol _|_ exang, thalach, sex, fbs | age, trestbps, heartdisease, restecg)
# (chol _|_ exang, sex | fbs, age, trestbps, restecg)
# (chol _|_ sex | exang, age, trestbps, thalach)
# (chol _|_ exang | age, trestbps, sex, thalach)
# (chol _|_ exang, sex, restecg, fbs | age, trestbps, heartdisease, thalach)
# (chol _|_ exang, sex | fbs, age, trestbps, thalach)
# (chol _|_ restecg, thalach, sex, fbs | exang, age, trestbps, heartdisease)
# (chol _|_ sex | exang, age, trestbps, fbs)
# (chol _|_ exang, fbs, restecg, thalach | age, trestbps, sex, heartdisease)
# (chol _|_ exang | age, trestbps, sex, fbs)
# (chol _|_ exang, sex, restecg, thalach | age, trestbps, heartdisease, fbs)
# (chol _|_ exang, trestbps, sex, fbs | age, thalach, heartdisease, restecg)
# (chol _|_ thalach, trestbps, sex, fbs | exang, age, heartdisease, restecg)
# (chol _|_ exang, thalach, trestbps, fbs | age, sex, heartdisease, restecg)
# (chol _|_ exang, trestbps, sex, thalach | fbs, age, heartdisease, restecg)
# (chol _|_ restecg, trestbps, sex, fbs | exang, age, heartdisease, thalach)
# (chol _|_ exang, trestbps, restecg, fbs | age, sex, heartdisease, thalach)
# (chol _|_ exang, trestbps, sex, restecg | fbs, age, heartdisease, thalach)
# (chol _|_ restecg, thalach, trestbps, fbs | exang, age, sex, heartdisease)
# (chol _|_ restecg, trestbps, sex, thalach | exang, age, heartdisease, fbs)
# (chol _|_ exang, trestbps, restecg, thalach | age, sex, heartdisease, fbs)
# (chol _|_ exang, age, sex, fbs | thalach, trestbps, heartdisease, restecg)
# (chol _|_ exang, age, sex | fbs, thalach, trestbps, restecg)
# (chol _|_ age, sex, thalach, fbs | exang, trestbps, heartdisease, restecg)
# (chol _|_ age, sex | exang, trestbps, fbs, restecg)
# (chol _|_ exang, age, thalach, fbs | trestbps, sex, heartdisease, restecg)
# (chol _|_ exang, age | fbs, trestbps, sex, restecg)
# (chol _|_ exang, age, sex, thalach | fbs, trestbps, heartdisease, restecg)
# (chol _|_ restecg, age, sex, fbs | exang, trestbps, heartdisease, thalach)
# (chol _|_ age, sex | exang, trestbps, fbs, thalach)
# (chol _|_ exang, age, restecg, fbs | trestbps, sex, heartdisease, thalach)
# (chol _|_ exang, age | fbs, trestbps, sex, thalach)
# (chol _|_ exang, age, sex, restecg | fbs, trestbps, heartdisease, thalach)
# (chol _|_ restecg, age, thalach, fbs | exang, trestbps, sex, heartdisease)
# (chol _|_ age | exang, trestbps, sex, fbs)
# (chol _|_ restecg, age, sex, thalach | exang, trestbps, heartdisease, fbs)
# (chol _|_ exang, age, restecg, thalach | trestbps, sex, heartdisease, fbs)
# (chol _|_ age, trestbps, sex, fbs | exang, thalach, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, fbs | thalach, sex, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, sex | fbs, thalach, heartdisease, restecg)
# (chol _|_ age, trestbps, thalach, fbs | exang, sex, heartdisease, restecg)
# (chol _|_ age, trestbps, sex, thalach | exang, fbs, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, thalach | fbs, sex, heartdisease, restecg)
# (chol _|_ restecg, age, trestbps, fbs | exang, sex, heartdisease, thalach)
# (chol _|_ age, trestbps, sex, restecg | exang, fbs, heartdisease, thalach)
# (chol _|_ exang, age, trestbps, restecg | fbs, sex, heartdisease, thalach)
# (chol _|_ restecg, age, trestbps, thalach | exang, sex, heartdisease, fbs)
# (chol _|_ sex | age, trestbps, thalach, restecg, exang)
# (chol _|_ exang | age, trestbps, thalach, restecg, sex)
# (chol _|_ exang, sex, fbs | age, trestbps, thalach, restecg, heartdisease)
# (chol _|_ exang, sex | age, trestbps, thalach, restecg, fbs)
# (chol _|_ thalach, sex, fbs | age, trestbps, restecg, exang, heartdisease)
# (chol _|_ sex | age, trestbps, restecg, exang, fbs)
# (chol _|_ exang, thalach, fbs | age, trestbps, restecg, sex, heartdisease)
# (chol _|_ exang | age, trestbps, restecg, sex, fbs)
# (chol _|_ exang, sex, thalach | age, trestbps, restecg, heartdisease, fbs)
# (chol _|_ restecg, sex, fbs | age, trestbps, thalach, exang, heartdisease)
# (chol _|_ sex | age, trestbps, thalach, exang, fbs)
# (chol _|_ exang, restecg, fbs | age, trestbps, thalach, sex, heartdisease)
# (chol _|_ exang | age, trestbps, thalach, sex, fbs)
# (chol _|_ exang, sex, restecg | age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, thalach, fbs | age, trestbps, exang, sex, heartdisease)
# (chol _|_ restecg, sex, thalach | age, trestbps, exang, heartdisease, fbs)
# (chol _|_ exang, restecg, thalach | age, trestbps, sex, heartdisease, fbs)
# (chol _|_ trestbps, sex, fbs | age, thalach, restecg, exang, heartdisease)
# (chol _|_ exang, trestbps, fbs | age, thalach, restecg, sex, heartdisease)
# (chol _|_ exang, trestbps, sex | age, thalach, restecg, heartdisease, fbs)
# (chol _|_ thalach, trestbps, fbs | age, restecg, exang, sex, heartdisease)
# (chol _|_ trestbps, sex, thalach | age, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, trestbps, thalach | age, restecg, sex, heartdisease, fbs)
# (chol _|_ restecg, trestbps, fbs | age, thalach, exang, sex, heartdisease)
# (chol _|_ trestbps, sex, restecg | age, thalach, exang, heartdisease, fbs)
# (chol _|_ exang, trestbps, restecg | age, thalach, sex, heartdisease, fbs)
# (chol _|_ restecg, trestbps, thalach | age, exang, sex, heartdisease, fbs)
# (chol _|_ age, sex, fbs | trestbps, thalach, restecg, exang, heartdisease)
# (chol _|_ age, sex | trestbps, thalach, restecg, exang, fbs)
# (chol _|_ exang, age, fbs | trestbps, thalach, restecg, sex, heartdisease)
# (chol _|_ exang, age | trestbps, thalach, restecg, sex, fbs)
# (chol _|_ exang, age, sex | trestbps, thalach, restecg, heartdisease, fbs)
# (chol _|_ age, thalach, fbs | trestbps, restecg, exang, sex, heartdisease)
# (chol _|_ age | trestbps, restecg, exang, sex, fbs)
# (chol _|_ age, sex, thalach | trestbps, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, age, thalach | trestbps, restecg, sex, heartdisease, fbs)
# (chol _|_ restecg, age, fbs | trestbps, thalach, exang, sex, heartdisease)
# (chol _|_ age | trestbps, thalach, exang, sex, fbs)
# (chol _|_ age, sex, restecg | trestbps, thalach, exang, heartdisease, fbs)
# (chol _|_ exang, age, restecg | trestbps, thalach, sex, heartdisease, fbs)
# (chol _|_ restecg, age, thalach | trestbps, exang, sex, heartdisease, fbs)
# (chol _|_ age, trestbps, fbs | thalach, restecg, exang, sex, heartdisease)
# (chol _|_ age, trestbps, sex | thalach, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, age, trestbps | thalach, restecg, sex, heartdisease, fbs)
# (chol _|_ age, trestbps, thalach | restecg, exang, sex, heartdisease, fbs)
# (chol _|_ age, trestbps, restecg | thalach, exang, sex, heartdisease, fbs)
# (chol _|_ sex, fbs | age, trestbps, thalach, restecg, exang, heartdisease)
# (chol _|_ sex | age, trestbps, thalach, restecg, exang, fbs)
# (chol _|_ exang, fbs | age, trestbps, thalach, restecg, sex, heartdisease)
# (chol _|_ exang | age, trestbps, thalach, restecg, sex, fbs)
# (chol _|_ exang, sex | age, trestbps, thalach, restecg, heartdisease, fbs)
# (chol _|_ thalach, fbs | age, trestbps, restecg, exang, sex, heartdisease)
# (chol _|_ sex, thalach | age, trestbps, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, thalach | age, trestbps, restecg, sex, heartdisease, fbs)
# (chol _|_ restecg, fbs | age, trestbps, thalach, exang, sex, heartdisease)
# (chol _|_ sex, restecg | age, trestbps, thalach, exang, heartdisease, fbs)
# (chol _|_ exang, restecg | age, trestbps, thalach, sex, heartdisease, fbs)
# (chol _|_ restecg, thalach | age, trestbps, exang, sex, heartdisease, fbs)
# (chol _|_ trestbps, fbs | age, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ trestbps, sex | age, thalach, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, trestbps | age, thalach, restecg, sex, heartdisease, fbs)
# (chol _|_ trestbps, thalach | age, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ trestbps, restecg | age, thalach, exang, sex, heartdisease, fbs)
# (chol _|_ age, fbs | trestbps, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ age | trestbps, thalach, restecg, exang, sex, fbs)
# (chol _|_ age, sex | trestbps, thalach, restecg, exang, heartdisease, fbs)
# (chol _|_ exang, age | trestbps, thalach, restecg, sex, heartdisease, fbs)
# (chol _|_ age, thalach | trestbps, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ age, restecg | trestbps, thalach, exang, sex, heartdisease, fbs)
# (chol _|_ age, trestbps | thalach, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ fbs | age, trestbps, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ sex | age, trestbps, thalach, restecg, exang, heartdisease, fbs)
# (chol _|_ exang | age, trestbps, thalach, restecg, sex, heartdisease, fbs)
# (chol _|_ thalach | age, trestbps, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ restecg | age, trestbps, thalach, exang, sex, heartdisease, fbs)
# (chol _|_ trestbps | age, thalach, restecg, exang, sex, heartdisease, fbs)
# (chol _|_ age | trestbps, thalach, restecg, exang, sex, heartdisease, fbs)

# %%
from pgmpy.inference import VariableElimination 

hd_infer=VariableElimination(model)
q=hd_infer.query(variables=['heartdisease'],evidence={'age':28})
print(q['heartdisease'])
q=hd_infer.query(variables=['heartdisease'], evidence={'chol': 100}) 
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              0.6333 |
# +----------------+---------------------+
# | heartdisease_1 |              0.3667 |
# +----------------+---------------------+
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              1.0000 |
# +----------------+---------------------+
# | heartdisease_1 |              0.0000 |
# +----------------+---------------------+
